# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('diamonds.csv')
df.head()
# Out:
#    Unnamed: 0    cut color clarity  carat_weight cut_quality  lab   symmetry  \
# 0           0  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 1           1  Round     E    VVS2          0.09   Very Good  IGI  Very Good
# 2           2  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 3           3  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 4           4  Round     E    VVS2          0.09   Very Good  IGI  Very Good
#
#       polish eye_clean  ... meas_depth girdle_min  girdle_max  fluor_color  \
# 0  Very Good   unknown  ...       1.79          M           M      unknown
# 1  Very Good   unknown  ...       1.78        STK         STK      unknown
# 2  Very Good   unknown  ...       1.77         TN           M      unknown
# 3  Very Good   unknown  ...       1.78          M         STK      unknown
# 4  Excellent   unknown  ...       1.82        STK         STK      unknown
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cut', 'color', 'clarity', 'carat_weight', 'cut_quality',
#        'lab', 'symmetry', 'polish', 'eye_clean', 'culet_size',
#        'culet_condition', 'depth_percent', 'table_percent', 'meas_length',
#        'meas_width', 'meas_depth', 'girdle_min', 'girdle_max', 'fluor_color',
#        'fluor_intensity', 'fancy_color_dominant_color',
#        'fancy_color_secondary_color', 'fancy_color_overtone',
#        'fancy_color_intensity', 'total_sales_price'],
#       dtype='object')

# %%
df.shape
# Out:
# (219703, 26)

# %%
df.describe()
# Out:
#           Unnamed: 0   carat_weight  depth_percent  table_percent  \
# count  219703.000000  219703.000000  219703.000000  219703.000000
# mean   109851.747418       0.755176      61.683768      57.747585
# std     63423.264419       0.845894       9.915266       9.959928
# min         0.000000       0.080000       0.000000       0.000000
# 25%     54925.500000       0.310000      61.200000      57.000000
# 50%    109852.000000       0.500000      62.400000      58.000000
# 75%    164777.500000       1.000000      63.500000      60.000000
# max    219703.000000      19.350000      98.700000      94.000000
#
#          meas_length     meas_width     meas_depth  total_sales_price
# count  219703.000000  219703.000000  219703.000000       2.197030e+05
# mean        5.548853       5.135626       3.285699       6.908062e+03
# std         1.763924       1.374529       2.054822       2.595949e+04
# min         0.000000       0.000000       0.000000       2.000000e+02
# ...

# %% [markdown]
# # **Discribing Data Attributes :**

# %% [markdown]
# # **EDA**

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.set_theme(style="whitegrid")
for axid, col in enumerate(["total_sales_price", "carat_weight"]):
    sns.boxplot(x=df[col], ax=ax[axid])

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.set_theme(style="whitegrid")
for axid, col in enumerate(["total_sales_price", "depth_percent"]):
    sns.boxplot(x=df[col], ax=ax[axid])

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

sns.set_theme(style="whitegrid")
for axid, col in enumerate(["meas_depth", "meas_width","meas_length"]):
    sns.boxplot(x=df[col], ax=ax[axid])

# %%
sns.scatterplot( x=df["cut_quality"],y=df["total_sales_price"])
# Out:
# <Axes: xlabel='cut_quality', ylabel='total_sales_price'>

# %%
sns.scatterplot( x=df["culet_size"],y=df["culet_condition"])
# Out:
# <Axes: xlabel='culet_size', ylabel='culet_condition'>

# %%
sns.scatterplot( x=df["clarity"],y=df["polish"])
# Out:
# <Axes: xlabel='clarity', ylabel='polish'>

# %%
sns.scatterplot( x=df["culet_size"],y=df["total_sales_price"])
# Out:
# <Axes: xlabel='culet_size', ylabel='total_sales_price'>

# %%
sns.scatterplot( x=df["carat_weight"],y=df["total_sales_price"])
# Out:
# <Axes: xlabel='carat_weight', ylabel='total_sales_price'>

# %% [markdown]
# Null value identification

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# cut                            0
# color                          0
# clarity                        0
# carat_weight                   0
# cut_quality                    0
# lab                            0
# symmetry                       0
# polish                         0
# eye_clean                      0
# culet_size                     0
# culet_condition                0
# depth_percent                  0
# table_percent                  0
# meas_length                    0
# meas_width                     0
# meas_depth                     0
# girdle_min                     0
# girdle_max                     0
# fluor_color                    0
# fluor_intensity                0
# fancy_color_dominant_color     0
# fancy_color_secondary_color    0
# fancy_color_overtone           0
# fancy_color_intensity          0
# total_sales_price              0
# dtype: int64

# %%
cut_quality_dist = df["cut_quality"].value_counts()
cut_quality_dist
# Out:
# Excellent    124861
# unknown       60607
# Very Good     34201
# Good             28
# Fair              5
# Ideal             1
# Name: cut_quality, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(cut_quality_dist)]
cut_quality_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='fluor_intensity'>

# %%
fluor_intensity_dist = df["fluor_intensity"].value_counts()
fluor_intensity_dist
# Out:
# None           143491
# Faint           38302
# Medium          20705
# Strong          13243
# Very Slight      2729
# Very Strong      1093
# unknown           128
# Slight             12
# Name: fluor_intensity, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(fluor_intensity_dist)]
fluor_intensity_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='fluor_intensity'>

# %%
girdle_min_dist = df["girdle_min"].value_counts()
girdle_min_dist
# Out:
# unknown    83432
# M          74421
# STK        26335
# TN         16744
# TK         10353
# VTK         4471
# XTK         1981
# VTN         1650
# XTN          292
# STN           24
# Name: girdle_min, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(girdle_min_dist)]
girdle_min_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='girdle_min'>

# %%
girdle_max_dist = df["girdle_max"].value_counts()
girdle_max_dist
# Out:
# unknown    84295
# STK        70440
# TK         25186
# M          17977
# VTK        12638
# XTK         7647
# TN          1363
# VTN          111
# XTN           34
# STN           12
# Name: girdle_max, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(girdle_max_dist)]
girdle_max_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='girdle_max'>

# %%
lab_dist = df["lab"].value_counts()
lab_dist
# Out:
# GIA    200434
# IGI     15865
# HRD      3404
# Name: lab, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(lab_dist)]
lab_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='lab'>

# %%
color_dist = df["color"].value_counts()
color_dist
# Out:
# E          33103
# F          31566
# D          30873
# G          29184
# H          26073
# I          22364
# J          16898
# K          11750
# unknown     9162
# L           5683
# M           3047
# Name: color, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(color_dist)]
color_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='color'>

# %%
clarity_dist = df["clarity"].value_counts()
clarity_dist
# Out:
# SI1     38627
# VS2     38173
# VS1     36956
# SI2     31105
# VVS2    28985
# VVS1    27877
# IF       9974
# I1       6961
# I2        944
# I3         91
# SI3        10
# Name: clarity, dtype: int64

# %%
piec_colors = sns.color_palette('pastel')[0:len(clarity_dist)]
clarity_dist.plot(kind = 'pie', colors=piec_colors, autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='clarity'>

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x=df["depth_percent"], y=df["table_percent"], hue=df["cut_quality"], size=df["symmetry"],  sizes=(10,100),legend="full")

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x=df["depth_percent"], y=df["table_percent"], hue=df["culet_condition"], size=df["eye_clean"],  sizes=(10,100),legend="full")

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x=df["total_sales_price"], y=df["table_percent"], hue=df["culet_condition"], size=df["eye_clean"],  sizes=(10,100),legend="full")
